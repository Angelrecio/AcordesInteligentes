# %% [markdown]
# # Instalación

# %%
# !pip install pytube
# !pip install pyktok
# !pip install browser_cookie3
# !pip install moviepy
# !pip install imageio imageio-ffmpeg numpy decorator tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytube in c:\users\ángel\appdata\roaming\python\python311\site-packages (15.0.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyktok in c:\users\ángel\appdata\roaming\python\python311\site-packages (0.0.19)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: browser_cookie3 in c:\users\ángel\appdata\roaming\python\python311\site-packages (0.19.1)
# Requirement already satisfied: lz4 in c:\programdata\anaconda3\lib\site-packages (from browser_cookie3) (4.3.2)
# Requirement already satisfied: pycryptodomex in c:\users\ángel\appdata\roaming\python\python311\site-packages (from browser_cookie3) (3.20.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting moviepy
#   Downloading moviepy-1.0.3.tar.gz (388 kB)
#      ---------------------------------------- 0.0/388.3 kB ? eta -:--:--
#      - -------------------------------------- 10.2/388.3 kB ? eta -:--:--
#      --- --------------------------------- 41.0/388.3 kB 495.5 kB/s eta 0:00:01
#      ------- ----------------------------- 81.9/388.3 kB 770.8 kB/s eta 0:00:01
#      ----------- ------------------------ 122.9/388.3 kB 722.1 kB/s eta 0:00:01
#      --------------- -------------------- 163.8/388.3 kB 821.4 kB/s eta 0:00:01
#      ------------------ ----------------- 194.6/388.3 kB 737.3 kB/s eta 0:00:01
#      -------------------- --------------- 225.3/388.3 kB 811.5 kB/s eta 0:00:01
#      -------------------- --------------- 225.3/388.3 kB 811.5 kB/s eta 0:00:01
#      -------------------- --------------- 225.3/388.3 kB 811.5 kB/s eta 0:00:01
#      -------------------- --------------- 225.3/388.3 kB 811.5 kB/s eta 0:00:01
#      ---------------------- ------------- 245.8/388.3 kB 503.2 kB/s eta 0:00:01
#      ----------------------- ------------ 256.0/388.3 kB 477.2 kB/s eta 0:00:01
#      -------------------------- --------- 286.7/388.3 kB 492.0 kB/s eta 0:00:01
#      ------------------------------ ----- 327.7/388.3 kB 521.2 kB/s eta 0:00:01
#      -----------------------------------  378.9/388.3 kB 562.0 kB/s eta 0:00:01
#      ------------------------------------ 388.3/388.3 kB 562.6 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting decorator<5.0,>=4.0.2 (from moviepy)
#   Obtaining dependency information for decorator<5.0,>=4.0.2 from https://files.pythonhosted.org/packages/ed/1b/72a1821152d07cf1d8b6fce298aeb06a7eb90f4d6d41acec9861e7cc6df0/decorator-4.4.2-py2.py3-none-any.whl.metadata
#   Downloading decorator-4.4.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in c:\programdata\anaconda3\lib\site-packages (from moviepy) (4.65.0)
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from moviepy) (2.31.0)
# Collecting proglog<=1.0.0 (from moviepy)
#   Obtaining dependency information for proglog<=1.0.0 from https://files.pythonhosted.org/packages/8b/f5/cab5cf6a540c31f5099043de0ae43990fd9cf66f75ecb5e9f254a4e4d4ee/proglog-0.1.10-py3-none-any.whl.metadata
#   Downloading proglog-0.1.10-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy>=1.17.3 in c:\programdata\anaconda3\lib\site-packages (from moviepy) (1.24.3)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from moviepy) (2.26.0)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy)
#   Obtaining dependency information for imageio_ffmpeg>=0.2.0 from https://files.pythonhosted.org/packages/c6/01/716106099e48c4f419876d5814679a94dd7d6f441217c97c1b608123c6bb/imageio_ffmpeg-0.4.9-py3-none-win_amd64.whl.metadata
#   Downloading imageio_ffmpeg-0.4.9-py3-none-win_amd64.whl.metadata (1.7 kB)
# Requirement already satisfied: pillow>=8.3.2 in c:\programdata\anaconda3\lib\site-packages (from imageio<3.0,>=2.5->moviepy) (9.4.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from imageio_ffmpeg>=0.2.0->moviepy) (68.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2023.7.22)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<5.0,>=4.11.2->moviepy) (0.4.6)
# Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
#
6 MB 1.8 MB/s eta 0:00:03
#    ------------------------------- -------- 17.7/22.6 MB 1.8 MB/s eta 0:00:03
#    ------------------------------- -------- 17.8/22.6 MB 1.8 MB/s eta 0:00:03
#    ------------------------------- -------- 17.9/22.6 MB 1.8 MB/s eta 0:00:03
#    ------------------------------- -------- 18.0/22.6 MB 1.8 MB/s eta 0:00:03
#    ------------------------------- -------- 18.1/22.6 MB 1.8 MB/s eta 0:00:03
#    -------------------------------- ------- 18.2/22.6 MB 1.8 MB/s eta 0:00:03
#    -------------------------------- ------- 18.3/22.6 MB 1.8 MB/s eta 0:00:03
#    -------------------------------- ------- 18.4/22.6 MB 1.8 MB/s eta 0:00:03
#    -------------------------------- ------- 18.5/22.6 MB 1.9 MB/s eta 0:00:03
#    -------------------------------- ------- 18.6/22.6 MB 1.9 MB/s eta 0:00:03
#    -------------------------------- ------- 18.7/22.6 MB 1.8 MB/s eta 0:00:03
#    --------------------------------- ------ 18.8/22.6 MB 1.8 MB/s eta 0:00:03
#    --------------------------------- ------ 18.8/22.6 MB 1.8 MB/s eta 0:00:03
#    --------------------------------- ------ 18.9/22.6 MB 1.8 MB/s eta 0:00:03
#    --------------------------------- ------ 19.0/22.6 MB 1.8 MB/s eta 0:00:02
#    --------------------------------- ------ 19.1/22.6 MB 1.8 MB/s eta 0:00:02
#    --------------------------------- ------ 19.1/22.6 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 19.3/22.6 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 19.4/22.6 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 19.4/22.6 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 19.5/22.6 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 19.7/22.6 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 19.7/22.6 MB 1.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 19.8/22.6 MB 1.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 19.9/22.6 MB 1.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 20.0/22.6 MB 1.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 20.1/22.6 MB 1.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 20.2/22.6 MB 1.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 20.3/22.6 MB 1.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 20.3/22.6 MB 1.9 MB/s eta 0:00:02
#    ------------------------------------ --- 20.4/22.6 MB 1.9 MB/s eta 0:00:02
#    ------------------------------------ --- 20.5/22.6 MB 1.9 MB/s eta 0:00:02
#    ------------------------------------ --- 20.6/22.6 MB 1.9 MB/s eta 0:00:02
#    ------------------------------------ --- 20.7/22.6 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------ --- 20.8/22.6 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------ --- 20.9/22.6 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 21.0/22.6 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 21.1/22.6 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 21.2/22.6 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 21.2/22.6 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 21.3/22.6 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 21.4/22.6 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 21.5/22.6 MB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 21.6/22.6 MB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 21.6/22.6 MB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 21.7/22.6 MB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 21.8/22.6 MB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 21.9/22.6 MB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 22.0/22.6 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  22.1/22.6 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  22.1/22.6 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  22.2/22.6 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  22.3/22.6 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  22.4/22.6 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  22.5/22.6 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  22.6/22.6 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  22.6/22.6 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 22.6/22.6 MB 1.9 MB/s eta 0:00:00
# Downloading proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Building wheels for collected packages: moviepy
#   Building wheel for moviepy (setup.py): started
#   Building wheel for moviepy (setup.py): finished with status 'done'
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110773 sha256=ba6e487997a6089df12f85444340119823ed40b8095c4860f312d581ddfc0732
#   Stored in directory: c:\users\ángel\appdata\local\pip\cache\wheels\83\b1\d9\119ef7c144b44d591ec0a9a140465133c23ea95d2a161184ba
# Successfully built moviepy
# Installing collected packages: imageio_ffmpeg, decorator, proglog, moviepy
# Successfully installed decorator-4.4.2 imageio_ffmpeg-0.4.9 moviepy-1.0.3 proglog-0.1.10
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imageio in c:\programdata\anaconda3\lib\site-packages (2.26.0)
# Requirement already satisfied: imageio-ffmpeg in c:\users\ángel\appdata\roaming\python\python311\site-packages (0.4.9)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (1.24.3)
# Requirement already satisfied: decorator in c:\users\ángel\appdata\roaming\python\python311\site-packages (4.4.2)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (4.65.0)
# Requirement already satisfied: pillow>=8.3.2 in c:\programdata\anaconda3\lib\site-packages (from imageio) (9.4.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from imageio-ffmpeg) (68.0.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm) (0.4.6)

# %% [markdown]
# # Descarga de vídeos

# %%
from pytube import YouTube
import pyktok as pyk
import requests
import os

def descargar_video(url):
    if "youtu" in url:
        print("Es YouTube")
        try:
            video = YouTube(url)
            video.streams.first().download()
            nombre_archivo = video.title + ".mp4"
        except Exception as e:
            print(f"Error al descargar el video de YouTube: {e}")
    elif "tiktok" in url:
        try:
            print("Es TikTok")
            # Descargar un video de TikTok y su metadato
            pyk.save_tiktok(enlace, True, 'video_data.csv', 'chrome')
            nombre_archivo = "video_tiktok.mp4"
        except Exception as e:
            print(f"Error al descargar el video de TikTok: {e}")
    else:
        print("Enlace no reconocido")

# Ejemplo de uso
enlaces = ['https://vm.tiktok.com/ZGefVUwVU/',"https://youtu.be/Cnm1cMqePSU?si=dZSaJ3gAyB3tLqex", "https://x.com/AMflashbacks/status/1767754617851695504?s=20"]

for enlace in enlaces:
    descargar_video(enlace)
# Out:
# Es TikTok
# Es TikTok
# Saved video
#  https://v16-webapp-prime.tiktok.com/video/tos/useast2a/tos-useast2a-ve-0068c001-euttp/o0HTPlHIjIYApeNfwXQgk2DLHfaFEGfwEgY0Dx/?a=1988&ch=0&cr=3&dr=0&lr=tiktok_m&cd=0%7C0%7C1%7C&cv=1&br=2198&bt=1099&bti=ODszNWYuMDE6&cs=0&ds=3&ft=4fUEKMUm8Zmo0kpSM94jVy47rpWrKsd.&mime_type=video_mp4&qs=0&rc=NWdoNDw3Z2lpOmc0NWU8ZEBpajpmN3I5cjpycTMzZjczM0AvYjAuLmIyNi0xLzQ0Yl4yYSNqZ2czMmRzYWVgLS1kMWNzcw%3D%3D&btag=e00090000&expire=1710773392&l=20240318084733B3A9ECF088C18A0CEF36&ply_type=2&policy=2&signature=ed7d558a44198f057b64f1a8981a9723&tk=tt_chain_token
# to
#  C:\Users\Ángel\Documents\TFG
# Saved metadata for video
#  https://vm.tiktok.com/ZGefVUwVU/
# to
#  C:\Users\Ángel\Documents\TFG
# Es YouTube
# Enlace no reconocido

# %% [markdown]
# # Transformación de los Mp4 a wav

# %%
import os
from moviepy.editor import VideoFileClip
import time

def mp4_to_wav(input_file, output_file):
    video = VideoFileClip(input_file)
    audio = video.audio
    audio.write_audiofile(output_file)
    # Cerrar el archivo de video para liberar el recurso
    video.close()
    # Esperar un breve período antes de intentar eliminar el archivo MP4
    time.sleep(1)  # Espera 1 segundo (puedes ajustar este valor según sea necesario)
    try:
        os.remove(input_file)
    except PermissionError:
        print(f"No se pudo eliminar {input_file} porque aún está siendo utilizado por otro proceso.")

# Verificar y crear el directorio de salida si no existe
output_dir = "audio"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Convertir archivos MP4 a WAV
for filename in os.listdir():
    if filename.endswith(".mp4"):
        input_file = filename
        output_file = os.path.join(output_dir, os.path.splitext(filename)[0] + ".wav")
        mp4_to_wav(input_file, output_file)
# Out:
#
# chunk:   1%|▎                                                           | 27/4755 [07:06<20:45:02, 15.80s/it, now=None]
# chunk:   1%|▎                                                           | 26/4755 [05:46<17:30:02, 13.32s/it, now=None]
# MoviePy - Writing audio in audio\buttercup - jack stauber (cover).wav
# chunk:   0%|                                                                        | 0/4755 [00:00<?, ?it/s, now=None]
#
# chunk:   5%|███                                                         | 243/4755 [00:00<00:01, 2427.94it/s, now=None]
#
# chunk:  13%|███████▉                                                    | 627/4755 [00:00<00:01, 3254.14it/s, now=None]
#
# chunk:  21%|████████████▌                                              | 1017/4755 [00:00<00:01, 3532.90it/s, now=None]
#
# chunk:  30%|█████████████████▋                                         | 1424/4755 [00:00<00:00, 3742.51it/s, now=None]
#
# chunk:  38%|██████████████████████▍                                    | 1805/4755 [00:00<00:00, 3756.09it/s, now=None]
#
# chunk:  46%|███████████████████████████                                | 2186/4755 [00:00<00:00, 3728.19it/s, now=None]
#
# chunk:  54%|███████████████████████████████▊                           | 2564/4755 [00:00<00:00, 3395.04it/s, now=None]
#
# chunk:  61%|████████████████████████████████████                       | 2911/4755 [00:00<00:00, 3198.32it/s, now=None]
#
# chunk:  68%|████████████████████████████████████████▏                  | 3237/4755 [00:00<00:00, 3010.86it/s, now=None]
#
# chunk:  75%|███████████████████████████████████████████▉               | 3545/4755 [00:01<00:00, 2876.20it/s, now=None]
#
# chunk:  81%|███████████████████████████████████████████████▋           | 3839/4755 [00:01<00:00, 2889.92it/s, now=None]
#
# chunk:  89%|████████████████████████████████████████████████████▎      | 4219/4755 [00:01<00:00, 3139.53it/s, now=None]
#
# chunk:  95%|████████████████████████████████████████████████████████▎  | 4539/4755 [00:01<00:00, 3032.08it/s, now=None]
#
#
# chunk:   1%|▎                                                           | 27/4755 [07:08<20:49:26, 15.86s/it, now=None]
# chunk:   1%|▎                                                           | 26/4755 [05:47<17:34:36, 13.38s/it, now=None]
# MoviePy - Done.
# No se pudo eliminar buttercup - jack stauber (cover).mp4 porque aún está siendo utilizado por otro proceso.
#
# chunk:   1%|▎                                                           | 27/4755 [07:09<20:53:09, 15.90s/it, now=None]
# chunk:   1%|▎                                                           | 26/4755 [05:49<17:38:28, 13.43s/it, now=None]
# MoviePy - Writing audio in audio\ZGefVUwVU_.wav
# chunk:   0%|                                                                        | 0/3049 [00:00<?, ?it/s, now=None]
#
# chunk:   8%|████▌                                                       | 234/3049 [00:00<00:01, 2317.38it/s, now=None]
#
# chunk:  19%|███████████▍                                                | 583/3049 [00:00<00:00, 2987.38it/s, now=None]
#
# chunk:  31%|██████████████████▍                                         | 935/3049 [00:00<00:00, 3224.08it/s, now=None]
#
# chunk:  43%|█████████████████████████                                  | 1296/3049 [00:00<00:00, 3365.48it/s, now=None]
#
# chunk:  55%|████████████████████████████████▎                          | 1669/3049 [00:00<00:00, 3483.83it/s, now=None]
#
# chunk:  67%|███████████████████████████████████████▍                   | 2040/3049 [00:00<00:00, 3514.25it/s, now=None]
#
# chunk:  79%|██████████████████████████████████████████████▍            | 2397/3049 [00:00<00:00, 3513.17it/s, now=None]
#
# chunk:  90%|█████████████████████████████████████████████████████▏     | 2750/3049 [00:00<00:00, 3372.83it/s, now=None]
#
#
# chunk:   1%|▎                                                           | 27/4755 [07:10<20:55:55, 15.94s/it, now=None]
# chunk:   1%|▎                                                           | 26/4755 [05:50<17:41:20, 13.47s/it, now=None]
# MoviePy - Done.

# %% [markdown]
# # Sacar la letra

# %%
# !pip install --upgrade git+https://github.com/huggingface/transformers.git accelerate datasets[audio]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to c:\users\ángel\appdata\local\temp\pip-req-build-8dpi9tt5
#   Resolved https://github.com/huggingface/transformers.git to commit 484e10f7f26b62452ba96488811a0c3f6eaf58df
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: accelerate in c:\users\ángel\appdata\roaming\python\python311\site-packages (0.28.0)
# Requirement already satisfied: datasets[audio] in c:\users\ángel\appdata\roaming\python\python311\site-packages (2.18.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from transformers==4.39.0.dev0) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\ángel\appdata\roaming\python\python311\site-packages (from transformers==4.39.0.dev0) (0.21.4)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from transformers==4.39.0.dev0) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from transformers==4.39.0.dev0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\lib\site-packages (from transformers==4.39.0.dev0) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\lib\site-packages (from transformers==4.39.0.dev0) (2022.7.9)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from transformers==4.39.0.dev0) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\ángel\appdata\roaming\python\python311\site-packages (from transformers==4.39.0.dev0) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\ángel\appdata\roaming\python\python311\site-packages (from transformers==4.39.0.dev0) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in c:\programdata\anaconda3\lib\site-packages (from transformers==4.39.0.dev0) (4.65.0)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: torch>=1.10.0 in c:\users\ángel\appdata\roaming\python\python311\site-packages (from accelerate) (2.2.1)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\ángel\appdata\roaming\python\python311\site-packages (from datasets[audio]) (15.0.2)
# Requirement already satisfied: pyarrow-hotfix in c:\users\ángel\appdata\roaming\python\python311\site-packages (from datasets[audio]) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from datasets[audio]) (0.3.6)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from datasets[audio]) (2.0.3)
# Requirement already satisfied: xxhash in c:\programdata\anaconda3\lib\site-packages (from datasets[audio]) (2.0.2)
# Requirement already satisfied: multiprocess in c:\programdata\anaconda3\lib\site-packages (from datasets[audio]) (0.70.14)
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in c:\users\ángel\appdata\roaming\python\python311\site-packages (from datasets[audio]) (2024.2.0)
# Requirement already satisfied: aiohttp in c:\programdata\anaconda3\lib\site-packages (from datasets[audio]) (3.8.5)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\ángel\appdata\roaming\python\python311\site-packages (from datasets[audio]) (0.12.1)
# Requirement already satisfied: librosa in c:\users\ángel\appdata\roaming\python\python311\site-packages (from datasets[audio]) (0.10.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets[audio]) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets[audio]) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets[audio]) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets[audio]) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets[audio]) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets[audio]) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets[audio]) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ángel\appdata\roaming\python\python311\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.39.0.dev0) (4.10.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers==4.39.0.dev0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers==4.39.0.dev0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers==4.39.0.dev0) (2023.7.22)
# Requirement already satisfied: cffi>=1.0 in c:\programdata\anaconda3\lib\site-packages (from soundfile>=0.12.1->datasets[audio]) (1.15.1)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (1.11.1)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.27->transformers==4.39.0.dev0) (0.4.6)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\ángel\appdata\roaming\python\python311\site-packages (from librosa->datasets[audio]) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from librosa->datasets[audio]) (1.11.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\programdata\anaconda3\lib\site-packages (from librosa->datasets[audio]) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in c:\programdata\anaconda3\lib\site-packages (from librosa->datasets[audio]) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\ángel\appdata\roaming\python\python311\site-packages (from librosa->datasets[audio]) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in c:\programdata\anaconda3\lib\site-packages (from librosa->datasets[audio]) (0.57.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\ángel\appdata\roaming\python\python311\site-packages (from librosa->datasets[audio]) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\ángel\appdata\roaming\python\python311\site-packages (from librosa->datasets[audio]) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in c:\programdata\anaconda3\lib\site-packages (from librosa->datasets[audio]) (0.2)
# Requirement already satisfied: msgpack>=1.0 in c:\programdata\anaconda3\lib\site-packages (from librosa->datasets[audio]) (1.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas->datasets[audio]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->datasets[audio]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->datasets[audio]) (2023.3)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->datasets[audio]) (2.21)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\programdata\anaconda3\lib\site-packages (from numba>=0.51.0->librosa->datasets[audio]) (0.40.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\programdata\anaconda3\lib\site-packages (from pooch>=1.0->librosa->datasets[audio]) (3.10.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets[audio]) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa->datasets[audio]) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git 'C:\Users\Ángel\AppData\Local\Temp\pip-req-build-8dpi9tt5'

# %%
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
from datasets import load_dataset


device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model_id = "openai/whisper-large-v3"

model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
)
model.to(device)

processor = AutoProcessor.from_pretrained(model_id)

pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    max_new_tokens=128,
    chunk_length_s=30,
    batch_size=16,
    return_timestamps=True,
    torch_dtype=torch_dtype,
    device=device,
)

dataset = load_dataset("distil-whisper/librispeech_long", "clean", split="validation")
sample = dataset[0]["audio"]

result = pipe("audio/ZGefVUwVU_.wav")
print(result["text"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import torch
#       2 from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
# ----> 3 from datasets import load_dataset
#       6 device = "cuda:0" if torch.cuda.is_available() else "cpu"
#       7 torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32
#
# File ~\AppData\Roaming\Python\Python311\site-packages\datasets\__init__.py:18
#       1 # ruff: noqa
#       2 # Copyright 2020 The HuggingFace Datasets Authors and the TensorFlow Datasets Authors.
#       3 #
#    (...)
#      13 # See the License for the specific language governing permissions and
#      14 # limitations under the License.
#      16 __version__ = "2.18.0"
# ---> 18 from .arrow_dataset import Dataset
#      19 from .arrow_reader import ReadInstruction
#      20 from .builder import ArrowBasedBuilder, BeamBasedBuilder, BuilderConfig, DatasetBuilder, GeneratorBasedBuilder
#
# File ~\AppData\Roaming\Python\Python311\site-packages\datasets\arrow_dataset.py:63
#      61 import pyarrow.compute as pc
#      62 from huggingface_hub import CommitInfo, CommitOperationAdd, CommitOperationDelete, DatasetCard, DatasetCardData, HfApi
# ---> 63 from multiprocess import Pool
#      64 from tqdm.contrib.concurrent import thread_map
#      66 from . import config
#
# ModuleNotFoundError: No module named 'multiprocess'

# %% [markdown]
# # Aislar el audio de instrumentos

# %%
# !pip install -U demucs
# or for local development, if you have a clone of Demucs
# pip install -e .
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting demucs
#   Downloading demucs-4.0.1.tar.gz (1.2 MB)
#      ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#      - -------------------------------------- 0.0/1.2 MB 495.5 kB/s eta 0:00:03
#      -- ------------------------------------- 0.1/1.2 MB 762.6 kB/s eta 0:00:02
#      ---- ----------------------------------- 0.1/1.2 MB 798.9 kB/s eta 0:00:02
#      ----- ---------------------------------- 0.2/1.2 MB 876.1 kB/s eta 0:00:02
#      ------- -------------------------------- 0.2/1.2 MB 919.0 kB/s eta 0:00:02
#      --------- ------------------------------ 0.3/1.2 MB 947.5 kB/s eta 0:00:01
#      ---------- ----------------------------- 0.3/1.2 MB 967.8 kB/s eta 0:00:01
#      ------------ --------------------------- 0.4/1.2 MB 955.7 kB/s eta 0:00:01
#      ------------- -------------------------- 0.4/1.2 MB 937.3 kB/s eta 0:00:01
#      ---------------- ----------------------- 0.5/1.2 MB 994.4 kB/s eta 0:00:01
#      ----------------- ---------------------- 0.5/1.2 MB 983.5 kB/s eta 0:00:01
#      ------------------- -------------------- 0.6/1.2 MB 992.1 kB/s eta 0:00:01
#      -------------------- ------------------- 0.6/1.2 MB 999.4 kB/s eta 0:00:01
#      --------------------- ------------------ 0.7/1.2 MB 975.2 kB/s eta 0:00:01
#      ----------------------- ---------------- 0.7/1.2 MB 982.7 kB/s eta 0:00:01
#      ------------------------- -------------- 0.8/1.2 MB 1.0 MB/s eta 0:00:01
#      --------------------------- ------------ 0.8/1.2 MB 996.3 kB/s eta 0:00:01
#      ---------------------------- ----------- 0.9/1.2 MB 1.0 MB/s eta 0:00:01
#      ----------------------------- ---------- 0.9/1.2 MB 999.9 kB/s eta 0:00:01
#      ------------------------------- -------- 1.0/1.2 MB 1.0 MB/s eta 0:00:01
#      --------------------------------- ------ 1.0/1.2 MB 993.3 kB/s eta 0:00:01
#      ---------------------------------- ----- 1.0/1.2 MB 993.2 kB/s eta 0:00:01
#      ---------------------------------- ----- 1.0/1.2 MB 973.9 kB/s eta 0:00:01
#      ------------------------------------ --- 1.1/1.2 MB 964.8 kB/s eta 0:00:01
#      ------------------------------------- -- 1.1/1.2 MB 969.8 kB/s eta 0:00:01
#      ---------------------------------------  1.2/1.2 MB 970.9 kB/s eta 0:00:01
#      ---------------------------------------- 1.2/1.2 MB 962.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dora-search (from demucs)
#   Downloading dora_search-0.1.12.tar.gz (87 kB)
#      ---------------------------------------- 0.0/87.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/87.1 kB ? eta -:--:--
#      -------------------------- ----------- 61.4/87.1 kB 812.7 kB/s eta 0:00:01
#      -------------------------------------- 87.1/87.1 kB 817.8 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting einops (from demucs)
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Collecting julius>=0.2.3 (from demucs)
#   Downloading julius-0.2.7.tar.gz (59 kB)
#      ---------------------------------------- 0.0/59.6 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/59.6 kB ? eta -:--:--
#      -------------------------------- ----- 51.2/59.6 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 59.6/59.6 kB 796.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting lameenc>=1.2 (from demucs)
#   Downloading lameenc-1.7.0-cp311-cp311-win_amd64.whl.metadata (825 bytes)
# Requirement already satisfied: openunmix in c:\users\ángel\appdata\roaming\python\python311\site-packages (from demucs) (1.2.1)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\lib\site-packages (from demucs) (6.0.1)
# Requirement already satisfied: torch>=1.8.1 in c:\users\ángel\appdata\roaming\python\python311\site-packages (from demucs) (2.2.1)
# Requirement already satisfied: torchaudio>=0.8 in c:\users\ángel\appdata\roaming\python\python311\site-packages (from demucs) (2.2.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from demucs) (4.65.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.1->demucs) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\ángel\appdata\roaming\python\python311\site-packages (from torch>=1.8.1->demucs) (4.10.0)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.1->demucs) (1.12)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.1->demucs) (3.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.1->demucs) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\ángel\appdata\roaming\python\python311\site-packages (from torch>=1.8.1->demucs) (2024.2.0)
# Collecting omegaconf (from dora-search->demucs)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting retrying (from dora-search->demucs)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Collecting submitit (from dora-search->demucs)
#   Downloading submitit-1.5.1-py3-none-any.whl.metadata (8.0 kB)
# Collecting treetable (from dora-search->demucs)
#   Downloading treetable-0.2.5.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from openunmix->demucs) (1.26.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->demucs) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch>=1.8.1->demucs) (2.1.3)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf->dora-search->demucs)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ---------------------------------------- 0.0/117.0 kB ? eta -:--:--
#      -------------------- ------------------ 61.4/117.0 kB 1.7 MB/s eta 0:00:01
#      ------------------------------------ - 112.6/117.0 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 117.0/117.0 kB 1.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from retrying->dora-search->demucs) (1.16.0)
# Requirement already satisfied: cloudpickle>=1.2.1 in c:\programdata\anaconda3\lib\site-packages (from submitit->dora-search->demucs) (2.2.1)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->torch>=1.8.1->demucs) (1.3.0)
# Downloading lameenc-1.7.0-cp311-cp311-win_amd64.whl (148 kB)
#    ---------------------------------------- 0.0/148.6 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/148.6 kB ? eta -:--:--
#    ---------- ---------------------------- 41.0/148.6 kB 991.0 kB/s eta 0:00:01
#    ------------------------ -------------- 92.2/148.6 kB 871.5 kB/s eta 0:00:01
#    ------------------------------------ - 143.4/148.6 kB 944.1 kB/s eta 0:00:01
#    -------------------------------------- 148.6/148.6 kB 886.6 kB/s eta 0:00:00
# Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/44.6 kB ? eta -:--:--
#    --------------------------- ------------ 30.7/44.6 kB 660.6 kB/s eta 0:00:01
#    ---------------------------------------- 44.6/44.6 kB 554.2 kB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ---------------------------------------- 0.0/79.5 kB ? eta -:--:--
#    --------------- ------------------------ 30.7/79.5 kB 1.3 MB/s eta 0:00:01
#    ------------------------------ --------- 61.4/79.5 kB 812.7 kB/s eta 0:00:01
#    ---------------------------------------- 79.5/79.5 kB 736.8 kB/s eta 0:00:00
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading submitit-1.5.1-py3-none-any.whl (74 kB)
#    ---------------------------------------- 0.0/74.7 kB ? eta -:--:--
#    ---------------- ----------------------- 30.7/74.7 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 74.7/74.7 kB 826.7 kB/s eta 0:00:00
# Building wheels for collected packages: demucs, julius, dora-search, antlr4-python3-runtime, treetable
#   Building wheel for demucs (setup.py): started
#   Building wheel for demucs (setup.py): finished with status 'done'
#   Created wheel for demucs: filename=demucs-4.0.1-py3-none-any.whl size=78462 sha256=dd9c91076931dd78471854c01d7e6a6ebf25a206aae52a97e549be72e43d4d2e
#   Stored in directory: c:\users\ángel\appdata\local\pip\cache\wheels\bb\06\a3\83489d50c9f015fa981a2a7bb08fcede75120a0de56775353f
#   Building wheel for julius (setup.py): started
#   Building wheel for julius (setup.py): finished with status 'done'
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21925 sha256=defbdaad3daafd6bb835ceab81da628a2edec9e98ce5683926491ec221ed43b2
#   Stored in directory: c:\users\ángel\appdata\local\pip\cache\wheels\16\15\d4\edd724cefe78050a6ba3344b8b0c6672db829a799dbb9f81ff
#   Building wheel for dora-search (pyproject.toml): started
#   Building wheel for dora-search (pyproject.toml): finished with status 'done'
#   Created wheel for dora-search: filename=dora_search-0.1.12-py3-none-any.whl size=75227 sha256=902b1b5df80bbceca738c08cb7e31bdf7fc26ea5ad043f284ac075a24dd5ad24
#   Stored in directory: c:\users\ángel\appdata\local\pip\cache\wheels\e3\f3\a9\2fd1ebbd64c4b2a1e53c81bf25282567a80802ceedfedcab4a
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144578 sha256=ca975f01438b07ede9073134e9dd375b9973ea19d9f251edb0e37bd5ee8b7450
#   Stored in directory: c:\users\ángel\appdata\local\pip\cache\wheels\1a\97\32\461f837398029ad76911109f07047fde1d7b661a147c7c56d1
#   Building wheel for treetable (setup.py): started
#   Building wheel for treetable (setup.py): finished with status 'done'
#   Created wheel for treetable: filename=treetable-0.2.5-py3-none-any.whl size=7369 sha256=36ef5a9bccfeb3134f519710f00499599a9f2d494baec3dbac7fdb3f0d9f06d5
#   Stored in directory: c:\users\ángel\appdata\local\pip\cache\wheels\6c\c9\6a\3ee58e3f4ed63e61de2a515cdb75438521f0372a1f0086be79
# Successfully built demucs julius dora-search antlr4-python3-runtime treetable
# Installing collected packages: lameenc, antlr4-python3-runtime, treetable, submitit, retrying, omegaconf, einops, julius, dora-search, demucs
# Successfully installed antlr4-python3-runtime-4.9.3 demucs-4.0.1 dora-search-0.1.12 einops-0.7.0 julius-0.2.7 lameenc-1.7.0 omegaconf-2.3.0 retrying-1.3.4 submitit-1.5.1 treetable-0.2.5
#   WARNING: The script dora.exe is installed in 'C:\Users\Ángel\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script demucs.exe is installed in 'C:\Users\Ángel\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import torch
import torchaudio
from demucs.apply import apply_model

# Cargar el archivo .wav
waveform, sample_rate = torchaudio.load("audio/ZGefVUwVU_.wav")

# Asegurarse de que el archivo tenga el formato correcto (2 canales y frecuencia de muestreo de 44100 Hz)
if waveform.shape[0] != 2 or sample_rate != 44100:
    raise ValueError("El archivo WAV debe tener 2 canales y una frecuencia de muestreo de 44100 Hz.")

# Normalizar la forma de onda si es necesario
waveform = waveform / torch.max(torch.abs(waveform))

# Convertir la forma de onda en tensores de PyTorch
x = waveform.unsqueeze(0)  # Agregar una dimensión para el lote

# Cargar el modelo DEMUCS pre-entrenado
from demucs import pretrained
model = pretrained.get_model('mdx')

# Aplicar el modelo al archivo de audio
out = apply_model(model, x)[0]  # El resultado tiene forma [S, C, T], donde S es el número de fuentes

# Sumar las fuentes, ignorando "vocals" si está presente
output_waveform = torch.zeros_like(waveform)
for i, source in enumerate(out):
    if model.sources[i] != "vocals":
        output_waveform += source

# Guardar el audio resultante sin la voz humana
torchaudio.save("output_without_vocals.wav", output_waveform, sample_rate)

# %% [markdown]
# # Pasar a espectrograma

# %%
# !pip install librosa

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np 

# Cargar el archivo de audio
audio_file = "output_without_vocals.wav"
y, sr = librosa.load(audio_file)

# Calcular el espectrograma
spectrogram = librosa.feature.melspectrogram(y=y, sr=sr)

# Visualizar el espectrograma
librosa.display.specshow(librosa.power_to_db(spectrogram, ref=np.max), y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel Spectrogram')
plt.show()
